# %%
from datasets import load_dataset

ds = load_dataset(
    "kunhanw/earning_call_transcript_dataset_with_volatility_analysis",
    cache_dir="C:/Users/ankit/Desktop/ToneShift/data/raw"
)
print(ds)
print(ds['train'][0])
# Out:
# Generating train split:   0%|          | 0/1831 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\datasets\builder.py:1863, in ArrowBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, job_id)
#    1862 try:
# -> 1863     writer = writer_class(
#    1864         features=self.info.features,
#    1865         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    1866         writer_batch_size=self._writer_batch_size,
#    1867         storage_options=self._fs.storage_options,
#    1868         embed_local_files=embed_local_files,
#    1869     )
#    1870     try:
#
# ...
